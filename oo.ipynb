# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
image_path = r"C:\Users\DELL\Desktop\myimage.jpg"  
image = Image.open(image_path).convert('L')
f = np.fft.fft2(image)  
fshift = np.fft.fftshift(f) 
magnitude_spectrum = 20*np.log1p(np.abs(fshift))

plt.subplot(121), plt.imshow(image, cmap='gray')
plt.title('Image Originale'), plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(magnitude_spectrum, cmap='gray')
plt.title('Représentation dans le domaine fréquentiel'), plt.xticks([]), plt.yticks([])
plt.show()

# Save the image of the frequency domain representation
plt.savefig(r"C:\Users\DELL\Desktop\frequency_domain_representation.jpg")

plt.show()

# Convert the numpy array to a PIL Image
magnitude_spectrum_image = Image.fromarray(magnitude_spectrum)

# Save the image of the frequency domain representation
magnitude_spectrum_image.save(r"C:\Users\DELL\Desktop\TFD.jpg")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\PIL\JpegImagePlugin.py:647, in _save(im, fp, filename)
#     646 try:
# --> 647     rawmode = RAWMODE[im.mode]
#     648 except KeyError as e:
#
# KeyError: 'F'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 25
#      22 magnitude_spectrum_image = Image.fromarray(magnitude_spectrum)
#      24 # Save the image of the frequency domain representation
# ---> 25 magnitude_spectrum_image.save(r"C:\Users\DELL\Desktop\TFD.jpg")
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\PIL\Image.py:2438, in Image.save(self, fp, format, **params)
#    2435         fp = builtins.open(filename, "w+b")
#    2437 try:
# -> 2438     save_handler(self, fp, filename)
#    2439 except Exception:
#    2440     if open_fp:
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\PIL\JpegImagePlugin.py:650, in _save(im, fp, filename)
#     648 except KeyError as e:
#     649     msg = f"cannot write mode {im.mode} as JPEG"
# --> 650     raise OSError(msg) from e
#     652 info = im.encoderinfo
#     654 dpi = [round(x) for x in info.get("dpi", (0, 0))]
#
# OSError: cannot write mode F as JPEG
